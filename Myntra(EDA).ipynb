# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudheshna-S/Myntra-EDA-/blob/main/Myntra(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Myntra Fashion Clothing EDA**
# ----------------------------------

# %% [markdown]
# 📌**Step 1: Import Libraries**
#
# 1. Pandas: Data manipulation and analysis
# 2. Numpy: Numerical operations and calculations
# 3. Matplotlib: Data visualization and plotting
# 4. Seaborn: Enhanced data visualization and statistical graphics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 📌 **Step 2: Data Loading and Exploration**

# %% [markdown]
# * Load a CSV file then creating a dataframe

# %%
df = pd.read_csv('/content/Myntra Fashion Clothing.csv')
# Out:
# /tmp/ipython-input-2959222215.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Myntra Fashion Clothing.csv')

# %% [markdown]
# * Quick overview of the data

# %%
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %% [markdown]
# * Check the column names

# %%
df.columns
# Out:
# Index(['URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %% [markdown]
# * shape of the dataset

# %%
print(f"The number of rows are {df.shape[0]} and columns are {df.shape[1]}")
# Out:
# The number of rows are 526564 and columns are 13

# %% [markdown]
# * Detailed info about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526564 entries, 0 to 526563
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   URL                    526564 non-null  object
#  1   Product_id             526564 non-null  int64
#  2   BrandName              526564 non-null  object
#  3   Category               526564 non-null  object
#  4   Individual_category    526564 non-null  object
#  5   category_by_Gender     526564 non-null  object
#  6   Description            526564 non-null  object
#  7   DiscountPrice (in Rs)  333406 non-null  float64
#  8   OriginalPrice (in Rs)  526564 non-null  float64
#  9   DiscountOffer          452258 non-null  object
#  10  SizeOption             526564 non-null  object
#  11  Ratings                190412 non-null  float64
#  12  Reviews                190412 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.2+ MB

# %% [markdown]
# *  Check for null values

# %%
df.isnull().sum()
# Out:
# URL                           0
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             74306
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %% [markdown]
# * Summary Statistics

# %%
df.describe()
# Out:
#          Product_id  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# count  5.265640e+05          333406.000000          526564.000000
# mean   1.506939e+07            1237.444401            2414.068615
# std    3.225710e+06            1052.063517            1916.962914
# min    2.739900e+04             127.000000              99.000000
# 25%    1.388053e+07             659.000000            1299.000000
# 50%    1.597106e+07             952.000000            1999.000000
# 75%    1.734741e+07            1469.000000            2899.000000
# max    1.846435e+07           27996.000000           90000.000000
#
#              Ratings        Reviews
# count  190412.000000  190412.000000
# mean        4.094892      61.990820
# std         0.494158     125.714537
# min         1.000000       0.000000
# 25%         3.900000       8.000000
# 50%         4.200000      18.000000
# 75%         4.400000      52.000000
# max         5.000000     999.000000

# %% [markdown]
# * Check unique values in categorical columns

# %%
for col in df.select_dtypes(include='object').columns:
  print(f'{col} --> {df[col].nunique()} unique values')
# Out:
# URL --> 526564 unique values
# BrandName --> 2088 unique values
# Category --> 8 unique values
# Individual_category --> 92 unique values
# category_by_Gender --> 2 unique values
# Description --> 429766 unique values
# DiscountOffer --> 1418 unique values
# SizeOption --> 3588 unique values

# %% [markdown]
# **Observation Set 1**
#
# - There are 526564 rows and 13 columns in the dataset.
# - The data type of columns are 4 float, 1 int64 and 8 objects
# - The columns in the datasets are:
#
#   'URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#   'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#   'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#   'Reviews'
#
# - There are a few missing values in DiscountPrice (in Rs)', 'DiscountOffer'and 'Reviews'

# %% [markdown]
# 📌 **Step 4: Handling Missing Values**

# %%
print(df['DiscountPrice (in Rs)'].isnull().sum() / len(df) * 100)
# Out:
# 36.68272042904566

# %%
print(df['DiscountPrice (in Rs)'].fillna(df['DiscountPrice (in Rs)'].median(), inplace=True))
# Out:
# None

# %%
print(df['DiscountPrice (in Rs)'].isnull().sum())
# Out:
# 0

# %%
df['Reviews'].fillna(0, inplace=True)

# %%
df['DiscountOffer'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# URL                      0
# Product_id               0
# BrandName                0
# Category                 0
# Individual_category      0
# category_by_Gender       0
# Description              0
# DiscountPrice (in Rs)    0
# OriginalPrice (in Rs)    0
# DiscountOffer            0
# SizeOption               0
# Ratings                  0
# Reviews                  0
# dtype: int64

# %% [markdown]
# 📌 **Step 5: Univariate Analysis**

# %%
df['OriginalPrice (in Rs)'].hist(bins=50, figsize=(8, 5))
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# - Prices are right-skewed (most products priced low/medium, few are premium).

# %%
sns.boxplot(x=df['OriginalPrice (in Rs)'])
plt.title("Boxplot of Prices")
plt.show()

# %% [markdown]
# - Boxplot shows outliers in high price range.

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x = df['BrandName'].value_counts().head(10).index, y=df['BrandName'].value_counts().head(10).values, hue=None, legend=False, palette= 'rocket')
plt.xlabel('Brand Name')
plt.ylabel('Frequency')
plt.title('Top 10 Popular Brands')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# - The Top 10 popular brands are Pothys, Roadster, Kalini and so on.

# %%
sns.countplot(x='category_by_Gender', data=df)
plt.title("Distribution by Gender")
plt.show()

# %% [markdown]
# - More products for Women’s fashion compared to Men’s.

# %% [markdown]
# 📌 **Step 5: Bivariate Analysis**

# %%
sns.scatterplot(x='OriginalPrice (in Rs)', y='Ratings', data =df, alpha=0.5)
plt.title("Price vs Rating")
plt.show()

# %% [markdown]
# -  Higher prices don’t always guarantee higher ratings.

# %%
top_categories = df['Individual_category'].value_counts().head(10).index
plt.figure(figsize=(12,6))
sns.boxplot(x='Individual_category', y='OriginalPrice (in Rs)', data=df[df['Individual_category'].isin(top_categories)])
plt.xticks(rotation=45)
plt.title("Top 10 Categories vs Price")
plt.show()

# %% [markdown]
# * Categories such as Sarees, Kurtas, and Dresses exhibit higher median prices and a wider range, reflecting both affordable and premium product segments.
# * In contrast, categories like Jeans, Shirts, and Tops maintain relatively lower and more consistent pricing.
# * Outliers in categories like Sarees and Dresses highlight the presence of luxury fashion products, whereas Bras emerge as the most affordable and uniform category.

# %% [markdown]
# 📌**Step 6: Correlation Analysis**

# %%
# Select only the numeric columns for correlation analysis, excluding 'Product_id'
numeric_df = df.select_dtypes(include=np.number).drop(columns=['Product_id'])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# * Price is positively correlated with discounted_price.
#
# * Ratings show weak correlation with prices.

# %%
sns.pairplot(df[['DiscountPrice (in Rs)', 'Ratings', 'DiscountOffer']].dropna())
plt.show()

# %% [markdown]
# * Discounts are common across all price ranges, but higher discounts appear in mid-priced items.

# %% [markdown]
# 📌**Summary of Findings**

# %% [markdown]
# * Dataset covers X brands & Y categories, dominated by women’s fashion.
#
# * Price distribution is right-skewed, with many affordable products and fewer luxury ones.
#
# * Top brands: Pothys, Roadster, Kalini and so on.
#
# * Category insights: Categories such as Sarees, Kurtas, and Dresses exhibit higher median prices and a wider range. and Categories like Jeans, Shirts, and Tops maintain relatively lower and more consistent pricing.
#
# * Ratings don’t strongly correlate with price → affordable products can perform as well as premium ones.
#
# * Discount trends: mid-range products often have larger discounts, possibly to boost sales.
